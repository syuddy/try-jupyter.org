# %%
# !pip install torch --quiet
import torch
import torch.nn as nn
import torch.optim as optim


# Create dummy data: y = 2x + 1
X = torch.randn(100, 1)
y = 2 * X + 1 + torch.randn(100, 1) * 0.1
my_data = [ X, y ]

# Print the entire DataFrame
print(my_data)
# Out:
# [tensor([[ 1.5093],
#         [ 1.0217],
#         [-0.3355],
#         [ 0.1695],
#         [-0.9666],
#         [-0.0128],
#         [-0.1232],
#         [ 0.6457],
#         [-1.3320],
#         [ 0.7691],
#         [-0.1027],
#         [ 1.2132],
#         [-1.8420],
#         [ 0.1484],
#         [-1.9340],
#         [-1.5718],
#         [ 0.1380],
#         [-0.8315],
#         [-2.2038],
#         [-0.0834],
#         [ 0.2310],
#         [ 0.7724],
#         [ 0.4366],
#         [-0.2000],
#         [-1.0280],
#         [-0.9358],
#         [ 0.6407],
#         [-0.8001],
#         [ 0.6205],
#         [ 0.9126],
#         [ 0.2420],
#         [ 0.1839],
#         [-1.5844],
#         [ 1.2299],
#         [ 0.0998],
#         [ 0.3333],
#         [-0.2556],
#         [-0.7459],
#         [-0.0210],
#         [ 1.2760],
#         [-0.1654],
#         [ 0.3189],
#         [ 1.6554],
#         [ 2.9199],
#         [ 1.8011],
#         [-1.7770],
#         [-0.7642],
#         [ 1.0902],
#         [ 1.3686],
#         [-0.4936],
#         [ 0.4967],
#         [ 0.9418],
#         [-1.2603],
#         [ 0.4691],
#         [ 0.5368],
#         [ 1.6259],
#         [-0.1553],
#         [-0.6683],
#         [-0.5123],
#         [-1.2162],
#         [-0.7918],
#         [-0.8647],
#         [-0.9194],
#         [ 0.3594],
#         [-1.8736],
#         [-0.9841],
#         [-1.1581],
#         [-1.9791],
#         [-0.3323],
#         [-1.6793],
#         [-2.0059],
#         [-0.1411],
#         [-0.2713],
#         [ 0.8517],
#         [ 0.4491],
#         [ 0.0567],
#         [ 0.6275],
#         [ 0.8770],
#         [ 0.7263],
#         [-0.3513],
#         [-1.9739],
#         [ 1.1144],
#         [ 1.3299],
#         [ 1.2797],
#         [-1.0222],
#         [-0.8883],
#         [ 1.0110],
#         [-0.2807],
#         [-0.7211],
#         [ 0.0718],
#         [ 0.0621],
#         [-1.3167],
#         [-1.2513],
#         [ 0.2097],
#         [ 0.0877],
#         [ 1.4798],
#         [ 1.7529],
#         [-1.0199],
#         [ 0.4207],
#         [ 1.0182]]), tensor([[ 3.9607],
#         [ 3.0382],
#         [ 0.3266],
#         [ 1.5600],
#         [-0.7878],
#         [ 1.0542],
#         [ 0.8961],
#         [ 2.1102],
#         [-1.6925],
#         [ 2.6657],
#         [ 0.7188],
#         [ 3.3986],
#         [-2.6390],
#         [ 1.2821],
#         [-2.8520],
#         [-2.2400],
#         [ 1.1843],
#         [-0.5203],
#         [-3.2754],
#         [ 0.7107],
#         [ 1.3001],
#         [ 2.5654],
#         [ 1.8795],
#         [ 0.3701],
#         [-1.0093],
#         [-0.8969],
#         [ 2.2144],
#         [-0.6463],
#         [ 2.2974],
#         [ 2.8097],
#         [ 1.3207],
#         [ 1.5046],
#         [-2.2641],
#         [ 3.3416],
#         [ 1.2366],
#         [ 1.6204],
#         [ 0.3139],
#         [-0.4371],
#         [ 0.9928],
#         [ 3.5533],
#         [ 0.7101],
#         [ 1.6723],
#         [ 4.2989],
#         [ 6.9495],
#         [ 4.6191],
#         [-2.6243],
#         [-0.5996],
#         [ 3.2507],
#         [ 3.5647],
#         [ 0.0093],
#         [ 1.9737],
#         [ 3.0056],
#         [-1.4152],
#         [ 1.9727],
#         [ 2.0779],
#         [ 4.1398],
#         [ 0.5839],
#         [-0.4088],
#         [ 0.0177],
#         [-1.3821],
#         [-0.7019],
#         [-0.6371],
#         [-0.8543],
#         [ 1.8415],
#         [-2.6758],
#         [-1.0559],
#         [-1.4684],
#         [-2.8008],
#         [ 0.5580],
#         [-2.3487],
#         [-3.1618],
#         [ 0.7720],
#         [ 0.5568],
#         [ 2.6454],
#         [ 1.9686],
#         [ 0.9308],
#         [ 2.3894],
#         [ 2.7956],
#         [ 2.3950],
#         [ 0.3748],
#         [-2.9107],
#         [ 3.2562],
#         [ 3.5875],
#         [ 3.3872],
#         [-0.9265],
#         [-0.8869],
#         [ 2.8398],
#         [ 0.3829],
#         [-0.2452],
#         [ 1.1720],
#         [ 1.3099],
#         [-1.6770],
#         [-1.5753],
#         [ 1.4183],
#         [ 1.0426],
#         [ 3.7325],
#         [ 4.4541],
#         [-1.0974],
#         [ 1.8258],
#         [ 3.0342]])]
